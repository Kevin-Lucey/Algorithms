# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevin-Lucey/Algorithms/blob/main/Lucey_W3HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn

iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['species'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# %% [markdown]
# Line Plot

# %%
from matplotlib.lines import lineStyles
x = df['species']
y = df['target']
plt.plot(x, y, marker='+', linestyle='--')

plt.xlabel('Species')
plt.ylabel('Target')
plt.title('Line Plot')

plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Bar Plot

# %%
x = df['species']
y = df['sepal length (cm)']

plt.bar(x, y)
plt.xlabel('Species')
plt.ylabel('Sepal. length (cm)')
plt.title('Sepal length by Species')
plt.show()

# %% [markdown]
# Scatter Plot

# %%
x = df['sepal length (cm)']
y = df['sepal width (cm)']

plt.scatter(x, y, marker='+')
plt.xlabel('Sepal. length (cm)')
plt.ylabel('Sepal. width (cm)')
plt.title('Scatter Plot')

plt.show()

# %% [markdown]
# Histogram

# %%
x = df['sepal length (cm)']

plt.hist(x, bins=3, edgecolor='black')
# Out:
# (array([52., 70., 28.]),
#  array([4.3, 5.5, 6.7, 7.9]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# Box plot

# %%
y = df['sepal length (cm)']

plt.boxplot(y, vert=True)
plt.xlabel('sepal length (cm)')
plt.show()

# %% [markdown]
# Seaborn

# %%
seaborn.scatterplot(data=df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
data = seaborn.load_dataset('tips')

seaborn.barplot(data=data, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
data.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
data = seaborn.load_dataset('fmri')

seaborn.lineplot(data=data, x='timepoint', y='signal', hue='region')
#
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
seaborn.pairplot(data=df, hue='species')
plt.title("Pair plot")
plt.show()
